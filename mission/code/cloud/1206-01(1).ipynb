# %%
from huggingface_hub import login
login(token="token")

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record_vscode_test\
  --dataset.root=${HOME}/lerobot/RainyNight17/rec_vscode_test \
  --policy.type=act \
  --output_dir=outputs/train/act_vscode-test--- \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test---
# Out:
# INFO 2025-12-06 23:53:38 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-two-cam \
  --dataset.root=${HOME}/lerobot_dataset/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-test-two-cam \
  --job_name=act_so101_test-two-cam \
  --steps 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-two-cam
# Out:
# INFO 2025-12-05 18:49:28 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record_vscode_test\
  --dataset.root=${HOME}/lerobot/RainyNight17/rec_vscode_test \
  --policy.type=act \
  --output_dir=outputs/train/act_vscode-test \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test
# Out:
# INFO 2025-12-06 23:55:55 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from datasets import load_dataset

ds = load_dataset("RainyNight17/record-test-two-cam")

print("observation keys:", ds["train"][0]["observation"].keys())

if "images" in ds["train"][0]["observation"]:
    print("image camera keys:", ds["train"][0]["observation"]["images"].keys())
else:
    print("No images found in dataset.")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/chunk-000/file-000.parquet:   0%|          | 0.00/539k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/13311 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 5
#       1 from datasets import load_dataset
#       3 ds = load_dataset("RainyNight17/record-test-two-cam")
# ----> 5 print("observation keys:", ds["train"][0]["observation"].keys())
#       7 if "images" in ds["train"][0]["observation"]:
#       8     print("image camera keys:", ds["train"][0]["observation"]["images"].keys())
#
# KeyError: 'observation'

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/rec_vscode_test\
  --dataset.root=${HOME}/lerobot/RainyNight17/rec_vscode_test \
  --policy.type=act \
  --output_dir=outputs/train/act_vscode-test \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/rec_vscode_test\
  --dataset.root=${HOME}/lerobot/RainyNight17/rec_vscode_test \
  --policy.type=act \
  --output_dir=outputs/train/act_vscode-test \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test
# Out:
# INFO 2025-12-06 23:57:13 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from datasets import load_dataset
ds = load_dataset("RainyNight17/record-test-two-cam")

print("Data example:")
print(ds["train"][0])
# Out:
# Data example:
# {'action': [4.609665393829346, -99.1478500366211, 99.72789001464844, 75.85004425048828, -57.228759765625, 1.618122935295105], 'observation.state': [4.9377760887146, -98.98348236083984, 99.36823272705078, 75.05451202392578, -56.992637634277344, 1.903467059135437], 'timestamp': 0.0, 'frame_index': 0, 'episode_index': 0, 'index': 0, 'task_index': 0}

# %%
--dataset.root=None
# Out:
#   Cell In[8], line 1
#     --dataset.root=None
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-two-cam \
  --dataset.root=${HOME}/record-test-two-cam/ \
  --policy.type=act \
  --rename_map='{"observation.images.front":"observation.images.front","observation.images.top":"observation.images.top"}' \
  --output_dir=outputs/train/act_so101-test-two-cam2 \
  --job_name=act_so101_test-two-cam \
  --steps 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-two-cam2
# Out:
# Traceback (most recent call last):
#   File "/opt/venv/bin/lerobot-train", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 444, in main
#     train()
#   File "/workspace/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 143, in train
#     cfg.validate()
#   File "/workspace/lerobot/src/lerobot/configs/train.py", line 110, in validate
#     raise FileExistsError(
# FileExistsError: Output directory outputs/train/act_so101-test-two-cam2 already exists and resume is False. Please change your output directory so that outputs/train/act_so101-test-two-cam2 is not overwritten.

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-two-cam \
  --dataset.root=${HOME}/lerobot_dataset/ \
  --policy.type=act \
  --rename_map='{"observation.images.front":"observation.images.front","observation.images.top":"observation.images.top"}' \
  --output_dir=outputs/train/act_so101-test-two-cam-modify-jonson \
  --job_name=act_so101_test-two-cam \
  --steps 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-two-cam2
# Out:
# INFO 2025-12-05 20:09:16 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-two-cam \
  --dataset.root=${HOME}/record-test-two-cam/ \
  --policy.type=act \
  --rename_map='{"observation.images.front":"observation.images.front","observation.images.top":"observation.images.top"}' \
  --output_dir=outputs/train/act_so101-test-two-cam3 \
  --job_name=act_so101_test-two-cam \
  --steps 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-two-cam3
# Out:
# INFO 2025-12-05 20:25:11 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-two-cam \
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --rename_map='{"observation.images.front":"observation.images.front","observation.images.top":"observation.images.top"}' \
  --output_dir=outputs/train/act_so101-test-two-cam3-1 \
  --job_name=act_so101_test-two-cam \
  --steps 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-two-cam3-1
# Out:
# INFO 2025-12-05 20:43:44 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three \
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-test-three \
  --job_name=act_so101_test-three \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-three
# Out:
# INFO 2025-12-05 23:04:08 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three-1 \
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-test-three-1 \
  --job_name=act_so101_test-three \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-three-1
# Out:
# INFO 2025-12-06 00:28:17 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three \
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-test-three-3 \
  --job_name=act_so101_test-three-3 \
  --step 5000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-test-three-3
# Out:
# INFO 2025-12-06 01:13:26 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three \
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=train/act_so101-three-model \
  --job_name=act_so101_three-model \
  --step 5000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-three-model
# Out:
# INFO 2025-12-06 01:54:55 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three \
  --dataset.root=${HOME}/RainyNight17/record-test-three \
  --policy.type=act \
  --output_dir=train/act_so101-three-model2 \
  --job_name=act_so101_three-model2 \
  --step 15000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-three-model2
# Out:
# INFO 2025-12-06 02:25:22 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three \
  --dataset.root=${HOME}/RainyNight17/record-test-three \
  --policy.type=act \
  --output_dir=train/act_so101-three-model2 \
  --job_name=act_so101_three-model2 \
  --step 15000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-three-model2
# Out:
# INFO 2025-12-06 02:47:39 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-project_ep5ep50\
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-project_ep5ep50 \
  --job_name=act_so101_project \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-project_ep5ep50
# Out:
# INFO 2025-12-06 08:06:19 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-project_ep5ep50\
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-project_ep5ep50 \
  --job_name=act_so101_project \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-project_ep5ep50
# Out:
# Traceback (most recent call last):
#   File "/opt/venv/bin/lerobot-train", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 444, in main
#     train()
#   File "/workspace/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 143, in train
#     cfg.validate()
#   File "/workspace/lerobot/src/lerobot/configs/train.py", line 110, in validate
#     raise FileExistsError(
# FileExistsError: Output directory outputs/train/act_so101-project_ep5ep50 already exists and resume is False. Please change your output directory so that outputs/train/act_so101-project_ep5ep50 is not overwritten.

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-project_ep5ep50\
  --dataset.root=${HOME}/lerobot/ \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-project_ep5ep50 \
  --job_name=act_so101_project \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-project_ep5ep50
# Out:
# INFO 2025-12-06 08:17:20 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-project_ep5ep50\
  --dataset.root=${HOME}/lerobot/RainyNight17/record-project_ep5ep50 \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-project_ep5ep50 \
  --job_name=act_so101_project \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-project_ep5ep50
# Out:
# INFO 2025-12-06 08:34:05 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-test-three\
  --dataset.root=${HOME}/lerobot/RainyNight17/record-test-three \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-project_ep50ep500 \
  --job_name=act_so101_project \
  --step 100000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-project_ep50ep500
# Out:
# INFO 2025-12-06 09:12:27 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/record-vscode-test\
  --dataset.root=${HOME}/lerobot/RainyNight17/record-vscode-test \
  --policy.type=act \
  --output_dir=outputs/train/act_so101-vscode-test \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test
# Out:
# INFO 2025-12-06 13:26:09 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...

# %%
from huggingface_hub import login
login(token="token")

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/rec_vscode_test\
  --dataset.root=${HOME}/lerobot/RainyNight17/rec_vscode_test \
  --policy.type=act \
  --output_dir=outputs/train/act_vscode-test \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test
# Out:
# Traceback (most recent call last):
#   File "/opt/venv/bin/lerobot-train", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 444, in main
#     train()
#   File "/workspace/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 143, in train
#     cfg.validate()
#   File "/workspace/lerobot/src/lerobot/configs/train.py", line 110, in validate
#     raise FileExistsError(
# FileExistsError: Output directory outputs/train/act_vscode-test already exists and resume is False. Please change your output directory so that outputs/train/act_vscode-test is not overwritten.

# %%
from huggingface_hub import login
login(token="token")
# !lerobot-train \
  --dataset.repo_id=RainyNight17/rec_vscode_test\
  --dataset.root=${HOME}/lerobot/RainyNight17/rec_vscode_test \
  --policy.type=act \
  --output_dir=outputs/train/act_vscode-test \
  --job_name=act_so101_vscode-test \
  --step 10000 \
  --policy.device=cuda \
  --wandb.enable=false \
  --policy.repo_id=RainyNight17/policy-vscode-test
# Out:
# INFO 2025-12-07 00:48:38 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
# ...
